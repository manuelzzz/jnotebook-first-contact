# %%
import pandas as pds
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="darkgrid")

# Jupyter captures the matplotlib and renders in cellout
# %matplotlib inline

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

linguagens = ['C++', 'Java', 'Python', 'PHP', 'Dart', 'JavaScript', 'Typescript']
quantidades = [1, 2, 6, 2, 8, 3, 4]

ax.bar(linguagens, quantidades)
# Out:
# <BarContainer object of 7 artists>
